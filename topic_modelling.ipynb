# %%
import pandas as pd
corona_review = pd.read_excel("Corona Reviews Cleaned.xlsx")
corona_review
# Out:
#       brand review_platform    review_type       date  \
# 0    Corona         Untappd  Online Review 2025-07-16
# 1    Corona         Untappd  Online Review 2025-07-16
# 2    Corona        Facebook   Social Media 2025-05-09
# 3    Corona         Twitter   Social Media 2025-07-17
# 4    Corona         Twitter   Social Media 2025-07-10
# ..      ...             ...            ...        ...
# 255  Corona        Facebook   Social Media 2025-09-10
# 256  Corona        Facebook   Social Media 2025-09-07
# 257  Corona         Untappd  Online Review 2025-09-18
# 258  Corona         Twitter   Social Media 2025-11-16
# 259  Corona           Forum  Online Review 2025-11-01
#
#                                                 review  \
# 0                                 Met limoen, heerlijk
# 1    On draught, so I had to try it. Not overly swe...
# 2    2+1 MIX AT WILL [emoji_winking_face_with_tongu...
# 3    @Anneke172351868 @hovewit I've heard this a fe...
# ...
